# %% [markdown]
# Segmentação de Imagens

# %%
# Instalando a biblioteca do YOLOv8
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.7/872.7 kB 21.5 MB/s eta 0:00:00
# ...

# %%
# Importando o pacote ultralytics
import ultralytics

# %%
# Importando as demais bibliotecas
import cv2
import matplotlib.pyplot as plt
import os
from PIL import Image
from google.colab.patches import cv2_imshow

# %%
# !yolo task=segment mode=predict model=yolov8m-seg.pt conf=0.2 source='/content/Mídia (3).jpg' save=True
# Out:
# Ultralytics YOLOv8.2.94 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8m-seg summary (fused): 245 layers, 27,268,704 parameters, 0 gradients, 110.2 GFLOPs
#
# image 1/1 /content/Mídia (3).jpg: 640x480 1 person, 1 motorcycle, 1 cat, 1 cup, 1579.2ms
# Speed: 5.2ms preprocess, 1579.2ms inference, 12.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/segment/predict11
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
resultado = cv2.imread('runs/segment/predict11/Mídia (3).jpg')
cv2_imshow(resultado)
# Out:
# <PIL.Image.Image image mode=RGB size=1247x1663>
