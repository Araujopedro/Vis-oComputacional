# %%
# Instalando a biblioteca do YOLOv8
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.7/872.7 kB 22.3 MB/s eta 0:00:00
# ...

# %%
# Importando o pacote ultralytics
import ultralytics

# %%
# Importando o pacote Pytorch
# Documentação: https://pytorch.org/

import torch

# %%
# Importando as demais bibliotecas
import cv2
from google.colab.patches import cv2_imshow

# %%
#YOLOV8 em funcionamneto
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/People_on_notebooks.png' save=True
# Out:
# Ultralytics YOLOv8.2.94 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/People_on_notebooks.png: 352x640 2 persons, 2 cups, 2 couchs, 3 potted plants, 3 laptops, 51.9ms
# Speed: 2.9ms preprocess, 51.9ms inference, 555.7ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Verifique se o caminho do arquivo está correto e se a imagem existe
# !ls runs/detect/predict2/content/

# Tente ler a imagem novamente com o caminho correto
resultado = cv2.imread('runs/detect/predict2/People_on_notebooks.png')

# Verifique se a imagem foi lida corretamente
if resultado is not None:
  cv2_imshow(resultado)
else:
  print("Erro ao ler a imagem. Verifique o caminho do arquivo.")
# Out:
# ls: cannot access 'runs/detect/predict2/content/': No such file or directory
# <PIL.Image.Image image mode=RGB size=1911x1030>
